# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import pandas as pd
import numpy as np
from nltk.util import ngrams
from collections import Counter

# %%
df = pd.read_excel('Attachment ambiguity WITH.xlsx')
df
# Out:
#    She walked into the room with a phone in her hand.
# 0   The chef cooked dinner, chopping vegetables an...
# 1   John entered the cafe with a phone tucked into...
# 2   She stood in line, chatting with the person ah...
# 3   The teenager sat on the bench with a phone in ...
# 4   The researcher conducted experiments, carefull...
# ..                                                ...
# 74  They went to the sports stadium with a phone a...
# 75  The explorer saw the world with a sense of adv...
# 76  She went to the planetarium with a phone and s...
# 77  She saw the silver lining in every cloud with ...
# 78  John went to the historic site with a phone an...
#
# [79 rows x 1 columns]

# %%
df.columns = ['Sentence']
df.head()
# Out:
#                                             Sentence
# 0  The chef cooked dinner, chopping vegetables an...
# 1  John entered the cafe with a phone tucked into...
# 2  She stood in line, chatting with the person ah...
# 3  The teenager sat on the bench with a phone in ...
# 4  The researcher conducted experiments, carefull...

# %%
def preprocess_text(text):
    tokens = word_tokenize(text.lower())
    tokens = [token for token in tokens if token.isalpha()]
    return tokens

df['tokens'] = df['Sentence'].apply(preprocess_text)
df.head()
# Out:
#                                             Sentence  \
# 0  The chef cooked dinner, chopping vegetables an...
# 1  John entered the cafe with a phone tucked into...
# 2  She stood in line, chatting with the person ah...
# 3  The teenager sat on the bench with a phone in ...
# 4  The researcher conducted experiments, carefull...
#
#                                               tokens
# 0  [the, chef, cooked, dinner, chopping, vegetabl...
# 1  [john, entered, the, cafe, with, a, phone, tuc...
# 2  [she, stood, in, line, chatting, with, the, pe...
# 3  [the, teenager, sat, on, the, bench, with, a, ...
# 4  [the, researcher, conducted, experiments, care...

# %%
def bi_gram(tokens):
    return list(ngrams(tokens,2))
df['bigrams'] = df['tokens'].apply(bi_gram)
df.head()
# Out:
#                                             Sentence  \
# 0  The chef cooked dinner, chopping vegetables an...
# 1  John entered the cafe with a phone tucked into...
# 2  She stood in line, chatting with the person ah...
# 3  The teenager sat on the bench with a phone in ...
# 4  The researcher conducted experiments, carefull...
#
#                                               tokens  \
# 0  [the, chef, cooked, dinner, chopping, vegetabl...
# 1  [john, entered, the, cafe, with, a, phone, tuc...
# 2  [she, stood, in, line, chatting, with, the, pe...
# 3  [the, teenager, sat, on, the, bench, with, a, ...
# 4  [the, researcher, conducted, experiments, care...
#
#                                              bigrams
# 0  [(the, chef), (chef, cooked), (cooked, dinner)...
# 1  [(john, entered), (entered, the), (the, cafe),...
# 2  [(she, stood), (stood, in), (in, line), (line,...
# 3  [(the, teenager), (teenager, sat), (sat, on), ...
# 4  [(the, researcher), (researcher, conducted), (...

# %%
all_tokens = []
for idx,row in df.iterrows():
    all_tokens.extend(row['tokens'])
all_tokens
token_count = Counter(all_tokens)
token_count
# Out:
# Counter({'the': 126,
#          'chef': 2,
#          'cooked': 2,
#          'dinner': 2,
#          'chopping': 1,
#          'vegetables': 1,
#          'and': 43,
#          'occasionally': 11,
#          'referring': 2,
#          'to': 27,
#          'recipes': 2,
#          'on': 23,
#          'a': 80,
#          'phone': 59,
#          'propped': 1,
#          'up': 2,
#          'counter': 2,
#          'john': 4,
#          'entered': 6,
#          'cafe': 2,
#          'with': 65,
#          'tucked': 3,
#          'into': 4,
#          'his': 7,
#          'pocket': 6,
#          'she': 17,
#          'stood': 2,
#          'in': 27,
#          'line': 2,
#          'chatting': 1,
#          'person': 3,
#          'ahead': 3,
#          'of': 15,
#          'her': 13,
#          'checking': 2,
#          'time': 1,
#          'hand': 5,
#          'teenager': 2,
#          'sat': 6,
#          'bench': 2,
#          'lost': 1,
#          'thought': 1,
#          'researcher': 2,
#          'conducted': 2,
#          'experiments': 2,
#          'carefully': 1,
#          'documenting': 1,
#          'their': 9,
#          'findings': 1,
#          'notes': 1,
#          'sarah': 4,
#          'hurried': 2,
#          'down': 5,
#          'street': 3,
#          'pressed': 1,
#          'ear': 1,
#          'they': 16,
#          'car': 2,
#          'discussing': 1,
#          'plans': 1,
#          'for': 5,
#          'day': 1,
#          'adjusting': 2,
#          'volume': 1,
#          'connected': 2,
#          'stereo': 2,
#          'system': 2,
#          'delivery': 2,
#          'arrived': 2,
#          'at': 8,
#          'doorstep': 2,
#          'buzzing': 3,
#          'doctor': 2,
#          'examination': 2,
#          'room': 5,
#          'greeted': 3,
#          'by': 3,
#          'sight': 3,
#          'patient': 1,
#          'desk': 1,
#          'he': 16,
#          'rushed': 2,
#          'through': 12,
#          'airport': 2,
#          'clutched': 1,
#          'tightly': 1,
#          'drove': 2,
#          'highway': 2,
#          'singing': 1,
#          'along': 1,
#          'radio': 1,
#          'glancing': 3,
#          'mounted': 2,
#          'dashboard': 2,
#          'navigation': 1,
#          'meeting': 2,
#          'resting': 1,
#          'table': 3,
#          'strolled': 2,
#          'park': 3,
#          'enjoying': 1,
#          'sunshine': 1,
#          'messages': 1,
#          'purse': 2,
#          'child': 2,
#          'ran': 2,
#          'around': 3,
#          'playground': 2,
#          'dangling': 1,
#          'from': 4,
#          'backpack': 1,
#          'wandered': 2,
#          'museum': 3,
#          'admiring': 1,
#          'artwork': 1,
#          'snapping': 1,
#          'photos': 1,
#          'camera': 1,
#          'café': 2,
#          'lying': 2,
#          'beside': 2,
#          'coffee': 3,
#          'cup': 1,
#          'librarian': 2,
#          'walked': 4,
#          'aisles': 2,
#          'shelving': 1,
#          'books': 2,
#          'pausing': 2,
#          'answer': 1,
#          'call': 3,
#          'clipped': 1,
#          'belt': 1,
#          'approached': 2,
#          'podium': 2,
#          'inner': 1,
#          'suit': 1,
#          'musician': 2,
#          'performed': 2,
#          'stage': 3,
#          'strumming': 1,
#          'guitar': 1,
#          'nearby': 2,
#          'stand': 1,
#          'placed': 2,
#          'amplifier': 1,
#          'microphone': 1,
#          'clearing': 1,
#          'throat': 1,
#          'before': 1,
#          'reaching': 1,
#          'peeking': 1,
#          'out': 1,
#          'sipping': 1,
#          'capturing': 1,
#          'every': 4,
#          'exhibit': 1,
#          'laughing': 1,
#          'friends': 1,
#          'take': 1,
#          'playing': 1,
#          'music': 1,
#          'sound': 1,
#          'chatter': 1,
#          'lighting': 1,
#          'conference': 2,
#          'searching': 1,
#          'gate': 1,
#          'one': 1,
#          'boarding': 1,
#          'pass': 1,
#          'other': 1,
#          'lab': 1,
#          'coat': 1,
#          'holding': 1,
#          'package': 1,
#          'struggling': 1,
#          'juggle': 1,
#          'groceries': 1,
#          'ringing': 1,
#          'bag': 1,
#          'recording': 1,
#          'step': 1,
#          'engrossed': 1,
#          'book': 1,
#          'forgotten': 1,
#          'them': 1,
#          'ready': 2,
#          'make': 1,
#          'if': 1,
#          'needed': 1,
#          'aroma': 1,
#          'check': 1,
#          'hands': 1,
#          'filled': 1,
#          'papers': 1,
#          'saw': 40,
#          'sunset': 1,
#          'sense': 4,
#          'wonder': 2,
#          'friend': 1,
#          'waiting': 1,
#          'corner': 1,
#          'deception': 1,
#          'keen': 1,
#          'eye': 2,
#          'traveled': 1,
#          'countryside': 1,
#          'breathtaking': 1,
#          'views': 1,
#          'nature': 1,
#          'world': 3,
#          'newfound': 1,
#          'clarity': 1,
#          'went': 15,
#          'concert': 1,
#          'favorite': 1,
#          'band': 1,
#          'perform': 1,
#          'live': 1,
#          'artist': 2,
#          'beauty': 2,
#          'simplicity': 1,
#          'stroke': 1,
#          'brush': 1,
#          'hike': 1,
#          'rare': 1,
#          'bird': 1,
#          'forest': 1,
#          'future': 1,
#          'uncertainty': 1,
#          'looming': 1,
#          'tourist': 1,
#          'explored': 1,
#          'city': 1,
#          'famous': 1,
#          'landmarks': 1,
#          'mist': 1,
#          'steady': 1,
#          'gaze': 1,
#          'attended': 1,
#          'inspiring': 1,
#          'speakers': 1,
#          'truth': 1,
#          'unclouded': 1,
#          'vision': 1,
#          'visited': 1,
#          'art': 1,
#          'gallery': 1,
#          'stunning': 1,
#          'paintings': 1,
#          'sculptures': 1,
#          'detective': 1,
#          'suspect': 1,
#          'alibi': 1,
#          'careful': 1,
#          'scrutiny': 1,
#          'beach': 1,
#          'dolphins': 1,
#          'swimming': 1,
#          'ocean': 1,
#          'potential': 1,
#          'project': 1,
#          'fresh': 2,
#          'perspective': 1,
#          'ancient': 2,
#          'artifacts': 2,
#          'different': 1,
#          'cultures': 1,
#          'flaws': 1,
#          'plan': 1,
#          'critical': 1,
#          'analysis': 1,
#          'student': 1,
#          'library': 1,
#          'rows': 1,
#          'various': 1,
#          'subjects': 1,
#          'humor': 1,
#          'situation': 1,
#          'shared': 1,
#          'laugh': 1,
#          'zoo': 1,
#          'exotic': 1,
#          'animals': 1,
#          'opportunity': 1,
#          'excitement': 1,
#          'amusement': 1,
#          'thrilling': 1,
#          'rides': 1,
#          'attractions': 1,
#          'chaos': 1,
#          'unfolding': 1,
#          'urgency': 1,
#          'botanical': 1,
#          'garden': 1,
#          'colorful': 1,
#          'flowers': 1,
#          'plants': 1,
#          'stars': 1,
#          'aquarium': 1,
#          'diverse': 1,
#          'marine': 1,
#          'life': 1,
#          'scientist': 1,
#          'patterns': 1,
#          'emerge': 1,
#          'each': 1,
#          'experiment': 1,
#          'theater': 1,
#          'captivating': 1,
#          'play': 1,
#          'imperfection': 1,
#          'an': 2,
#          'market': 1,
#          'produce': 1,
#          'local': 1,
#          'goods': 1,
#          'danger': 1,
#          'quick': 1,
#          'assessment': 1,
#          'observatory': 1,
#          'distant': 1,
#          'galaxies': 1,
#          'telescope': 1,
#          'challenges': 1,
#          'determination': 1,
#          'hearts': 1,
#          'sports': 1,
#          'stadium': 1,
#          'intense': 1,
#          'match': 1,
#          'between': 1,
#          'rival': 1,
#          'teams': 1,
#          'explorer': 1,
#          'adventure': 1,
#          'planetarium': 1,
#          'fascinating': 1,
#          'presentation': 1,
#          'about': 1,
#          'cosmos': 1,
#          'silver': 1,
#          'lining': 1,
#          'cloud': 1,
#          'optimism': 1,
#          'historic': 1,
#          'site': 1,
#          'civilizations': 1})

# %%
all_bigram = []
for idx,row in df.iterrows():
    all_bigram.extend(row['bigrams'])
bigram_count = Counter(all_bigram)
bigram_count
# Out:
# Counter({('the', 'chef'): 2,
#          ('chef', 'cooked'): 2,
#          ('cooked', 'dinner'): 2,
#          ('dinner', 'chopping'): 1,
#          ('chopping', 'vegetables'): 1,
#          ('vegetables', 'and'): 1,
#          ('and', 'occasionally'): 11,
#          ('occasionally', 'referring'): 2,
#          ('referring', 'to'): 2,
#          ('to', 'recipes'): 1,
#          ('recipes', 'on'): 1,
#          ('on', 'a'): 8,
#          ('a', 'phone'): 59,
#          ('phone', 'propped'): 1,
#          ('propped', 'up'): 1,
#          ('up', 'on'): 2,
#          ('on', 'the'): 11,
#          ('the', 'counter'): 2,
#          ('john', 'entered'): 2,
#          ('entered', 'the'): 6,
#          ('the', 'cafe'): 2,
#          ('cafe', 'with'): 1,
#          ('with', 'a'): 51,
#          ('phone', 'tucked'): 3,
#          ('tucked', 'into'): 3,
#          ('into', 'his'): 1,
#          ('his', 'pocket'): 2,
#          ('she', 'stood'): 2,
#          ('stood', 'in'): 2,
#          ('in', 'line'): 2,
#          ('line', 'chatting'): 1,
#          ('chatting', 'with'): 1,
#          ('with', 'the'): 1,
#          ('the', 'person'): 1,
#          ('person', 'ahead'): 1,
#          ('ahead', 'of'): 1,
#          ('of', 'her'): 2,
#          ('her', 'and'): 1,
#          ('occasionally', 'checking'): 2,
#          ('checking', 'the'): 1,
#          ('the', 'time'): 1,
#          ('time', 'on'): 1,
#          ('phone', 'in'): 6,
#          ('in', 'her'): 5,
#          ('her', 'hand'): 2,
#          ('the', 'teenager'): 2,
#          ('teenager', 'sat'): 2,
#          ('sat', 'on'): 2,
#          ('the', 'bench'): 2,
#          ('bench', 'with'): 1,
#          ('in', 'hand'): 1,
#          ('hand', 'lost'): 1,
#          ('lost', 'in'): 1,
#          ('in', 'thought'): 1,
#          ('the', 'researcher'): 2,
#          ('researcher', 'conducted'): 2,
#          ('conducted', 'experiments'): 2,
#          ('experiments', 'carefully'): 1,
#          ('carefully', 'documenting'): 1,
#          ('documenting', 'their'): 1,
#          ('their', 'findings'): 1,
#          ('findings', 'and'): 1,
#          ('to', 'notes'): 1,
#          ('notes', 'on'): 1,
#          ('sarah', 'hurried'): 2,
#          ('hurried', 'down'): 2,
#          ('down', 'the'): 5,
#          ('the', 'street'): 3,
#          ('street', 'with'): 2,
#          ('phone', 'pressed'): 1,
#          ('pressed', 'to'): 1,
#          ('to', 'her'): 1,
#          ('her', 'ear'): 1,
#          ('they', 'sat'): 2,
#          ('sat', 'in'): 2,
#          ('in', 'the'): 8,
#          ('the', 'car'): 2,
#          ('car', 'discussing'): 1,
#          ('discussing', 'their'): 1,
#          ('their', 'plans'): 1,
#          ('plans', 'for'): 1,
#          ('for', 'the'): 1,
#          ('the', 'day'): 1,
#          ('day', 'and'): 1,
#          ('occasionally', 'adjusting'): 1,
#          ('adjusting', 'the'): 2,
#          ('the', 'volume'): 1,
#          ('volume', 'on'): 1,
#          ('phone', 'connected'): 2,
#          ('connected', 'to'): 2,
#          ('to', 'the'): 18,
#          ('the', 'stereo'): 2,
#          ('stereo', 'system'): 2,
#          ('the', 'delivery'): 2,
#          ('delivery', 'person'): 2,
#          ('person', 'arrived'): 2,
#          ('arrived', 'at'): 2,
#          ('at', 'the'): 5,
#          ('the', 'doorstep'): 2,
#          ('doorstep', 'with'): 1,
#          ('phone', 'buzzing'): 3,
#          ('buzzing', 'in'): 2,
#          ('in', 'their'): 3,
#          ('their', 'pocket'): 2,
#          ('the', 'doctor'): 2,
#          ('doctor', 'entered'): 2,
#          ('the', 'examination'): 2,
#          ('examination', 'room'): 2,
#          ('room', 'greeted'): 2,
#          ('greeted', 'by'): 3,
#          ('by', 'the'): 3,
#          ('the', 'sight'): 3,
#          ('sight', 'of'): 3,
#          ('of', 'a'): 3,
#          ('a', 'patient'): 1,
#          ('patient', 'and'): 1,
#          ('and', 'a'): 4,
#          ('buzzing', 'on'): 1,
#          ('the', 'desk'): 1,
#          ('he', 'rushed'): 2,
#          ('rushed', 'through'): 2,
#          ('through', 'the'): 11,
#          ('the', 'airport'): 2,
#          ('airport', 'with'): 1,
#          ('phone', 'clutched'): 1,
#          ('clutched', 'tightly'): 1,
#          ('tightly', 'in'): 1,
#          ('in', 'his'): 2,
#          ('his', 'hand'): 1,
#          ('he', 'drove'): 2,
#          ('drove', 'down'): 2,
#          ('the', 'highway'): 2,
#          ('highway', 'singing'): 1,
#          ('singing', 'along'): 1,
#          ('along', 'to'): 1,
#          ('the', 'radio'): 1,
#          ('radio', 'and'): 1,
#          ('occasionally', 'glancing'): 3,
#          ('glancing', 'at'): 3,
#          ('at', 'a'): 3,
#          ('phone', 'mounted'): 2,
#          ('mounted', 'on'): 2,
#          ('the', 'dashboard'): 2,
#          ('dashboard', 'for'): 1,
#          ('for', 'navigation'): 1,
#          ('they', 'entered'): 2,
#          ('the', 'meeting'): 2,
#          ('meeting', 'room'): 2,
#          ('room', 'with'): 2,
#          ('phone', 'resting'): 1,
#          ('resting', 'on'): 1,
#          ('the', 'table'): 2,
#          ('she', 'strolled'): 2,
#          ('strolled', 'through'): 2,
#          ('the', 'park'): 2,
#          ('park', 'enjoying'): 1,
#          ('enjoying', 'the'): 1,
#          ('the', 'sunshine'): 1,
#          ('sunshine', 'and'): 1,
#          ('checking', 'messages'): 1,
#          ('messages', 'on'): 1,
#          ('her', 'purse'): 2,
#          ('the', 'child'): 2,
#          ('child', 'ran'): 2,
#          ('ran', 'around'): 2,
#          ('around', 'the'): 3,
#          ('the', 'playground'): 2,
#          ('playground', 'with'): 1,
#          ('phone', 'dangling'): 1,
#          ('dangling', 'from'): 1,
#          ('from', 'their'): 1,
#          ('their', 'backpack'): 1,
#          ('they', 'wandered'): 2,
#          ('wandered', 'through'): 2,
#          ('the', 'museum'): 3,
#          ('museum', 'admiring'): 1,
#          ('admiring', 'the'): 1,
#          ('the', 'artwork'): 1,
#          ('artwork', 'and'): 1,
#          ('occasionally', 'snapping'): 1,
#          ('snapping', 'photos'): 1,
#          ('photos', 'with'): 1,
#          ('phone', 'camera'): 1,
#          ('she', 'sat'): 2,
#          ('sat', 'at'): 2,
#          ('the', 'café'): 2,
#          ('café', 'with'): 1,
#          ('phone', 'lying'): 2,
#          ('lying', 'beside'): 1,
#          ('beside', 'her'): 1,
#          ('her', 'coffee'): 2,
#          ('coffee', 'cup'): 1,
#          ('the', 'librarian'): 2,
#          ('librarian', 'walked'): 2,
#          ('walked', 'through'): 2,
#          ('the', 'aisles'): 2,
#          ('aisles', 'shelving'): 1,
#          ('shelving', 'books'): 1,
#          ('books', 'and'): 1,
#          ('occasionally', 'pausing'): 2,
#          ('pausing', 'to'): 2,
#          ('to', 'answer'): 1,
#          ('answer', 'a'): 1,
#          ('a', 'call'): 3,
#          ('call', 'on'): 2,
#          ('phone', 'clipped'): 1,
#          ('clipped', 'to'): 1,
#          ('to', 'their'): 1,
#          ('their', 'belt'): 1,
#          ('he', 'approached'): 2,
#          ('approached', 'the'): 2,
#          ('the', 'podium'): 2,
#          ('podium', 'with'): 1,
#          ('into', 'the'): 3,
#          ('the', 'inner'): 1,
#          ('inner', 'pocket'): 1,
#          ('pocket', 'of'): 1,
#          ('of', 'his'): 1,
#          ('his', 'suit'): 1,
#          ('the', 'musician'): 2,
#          ('musician', 'performed'): 2,
#          ('performed', 'on'): 2,
#          ('on', 'stage'): 3,
#          ('stage', 'strumming'): 1,
#          ('strumming', 'their'): 1,
#          ('their', 'guitar'): 1,
#          ('guitar', 'and'): 1,
#          ('phone', 'on'): 2,
#          ('a', 'nearby'): 1,
#          ('nearby', 'stand'): 1,
#          ('stage', 'with'): 1,
#          ('phone', 'placed'): 2,
#          ('placed', 'on'): 2,
#          ('the', 'amplifier'): 1,
#          ('podium', 'adjusting'): 1,
#          ('the', 'microphone'): 1,
#          ('microphone', 'and'): 1,
#          ('and', 'clearing'): 1,
#          ('clearing', 'his'): 1,
#          ('his', 'throat'): 1,
#          ('throat', 'before'): 1,
#          ('before', 'reaching'): 1,
#          ('reaching', 'for'): 1,
#          ('for', 'a'): 2,
#          ('aisles', 'with'): 1,
#          ('phone', 'peeking'): 1,
#          ('peeking', 'out'): 1,
#          ('out', 'of'): 1,
#          ('her', 'pocket'): 1,
#          ('café', 'sipping'): 1,
#          ('sipping', 'her'): 1,
#          ('coffee', 'and'): 2,
#          ('museum', 'with'): 2,
#          ('phone', 'capturing'): 1,
#          ('capturing', 'every'): 1,
#          ('every', 'exhibit'): 1,
#          ('playground', 'laughing'): 1,
#          ('laughing', 'with'): 1,
#          ('with', 'friends'): 1,
#          ('friends', 'and'): 1,
#          ('to', 'take'): 1,
#          ('take', 'a'): 1,
#          ('park', 'with'): 2,
#          ('phone', 'playing'): 1,
#          ('playing', 'music'): 1,
#          ('music', 'in'): 1,
#          ('the', 'sound'): 1,
#          ('sound', 'of'): 1,
#          ('of', 'chatter'): 1,
#          ('chatter', 'and'): 1,
#          ('and', 'the'): 2,
#          ('phone', 'lighting'): 1,
#          ('lighting', 'up'): 1,
#          ('the', 'conference'): 2,
#          ('conference', 'table'): 1,
#          ('highway', 'with'): 1,
#          ('airport', 'searching'): 1,
#          ('searching', 'for'): 1,
#          ('for', 'his'): 1,
#          ('his', 'gate'): 1,
#          ('gate', 'with'): 1,
#          ('in', 'one'): 1,
#          ('one', 'hand'): 1,
#          ('hand', 'and'): 1,
#          ('and', 'his'): 1,
#          ('his', 'boarding'): 1,
#          ('boarding', 'pass'): 1,
#          ('pass', 'in'): 1,
#          ('the', 'other'): 1,
#          ('the', 'lab'): 1,
#          ('lab', 'coat'): 1,
#          ('doorstep', 'holding'): 1,
#          ('holding', 'a'): 1,
#          ('a', 'package'): 1,
#          ('package', 'and'): 1,
#          ('car', 'with'): 1,
#          ('street', 'struggling'): 1,
#          ('struggling', 'to'): 1,
#          ('to', 'juggle'): 1,
#          ('juggle', 'her'): 1,
#          ('her', 'groceries'): 1,
#          ('groceries', 'and'): 1,
#          ('phone', 'ringing'): 1,
#          ('ringing', 'in'): 1,
#          ('her', 'bag'): 1,
#          ('experiments', 'with'): 1,
#          ('phone', 'recording'): 1,
#          ('recording', 'every'): 1,
#          ('every', 'step'): 1,
#          ('bench', 'engrossed'): 1,
#          ('engrossed', 'in'): 1,
#          ('in', 'a'): 1,
#          ('a', 'book'): 1,
#          ('book', 'with'): 1,
#          ('lying', 'forgotten'): 1,
#          ('forgotten', 'beside'): 1,
#          ('beside', 'them'): 1,
#          ('line', 'with'): 1,
#          ('purse', 'ready'): 1,
#          ('ready', 'to'): 2,
#          ('to', 'make'): 1,
#          ('make', 'a'): 1,
#          ('call', 'if'): 1,
#          ('if', 'needed'): 1,
#          ('cafe', 'greeted'): 1,
#          ('the', 'aroma'): 1,
#          ('aroma', 'of'): 1,
#          ('of', 'coffee'): 1,
#          ('dinner', 'with'): 1,
#          ('phone', 'nearby'): 1,
#          ('nearby', 'ready'): 1,
#          ('to', 'check'): 1,
#          ('check', 'recipes'): 1,
#          ('she', 'walked'): 2,
#          ('walked', 'into'): 1,
#          ('the', 'room'): 1,
#          ('room', 'her'): 1,
#          ('her', 'hands'): 1,
#          ('hands', 'filled'): 1,
#          ('filled', 'with'): 1,
#          ('with', 'papers'): 1,
#          ('papers', 'and'): 1,
#          ('she', 'saw'): 6,
#          ('saw', 'the'): 15,
#          ('the', 'sunset'): 1,
#          ('sunset', 'with'): 1,
#          ('a', 'sense'): 4,
#          ('sense', 'of'): 4,
#          ('of', 'wonder'): 1,
#          ('walked', 'down'): 1,
#          ('phone', 'and'): 20,
#          ('and', 'saw'): 20,
#          ('saw', 'her'): 1,
#          ('her', 'friend'): 1,
#          ('friend', 'waiting'): 1,
#          ('waiting', 'at'): 1,
#          ('the', 'corner'): 1,
#          ('he', 'saw'): 5,
#          ('saw', 'through'): 3,
#          ('the', 'deception'): 1,
#          ('deception', 'with'): 1,
#          ('a', 'keen'): 1,
#          ('keen', 'eye'): 1,
#          ('he', 'traveled'): 1,
#          ('traveled', 'to'): 1,
#          ('the', 'countryside'): 1,
#          ('countryside', 'with'): 1,
#          ('saw', 'breathtaking'): 1,
#          ('breathtaking', 'views'): 1,
#          ('views', 'of'): 1,
#          ('of', 'nature'): 1,
#          ('they', 'saw'): 5,
#          ('the', 'world'): 3,
#          ('world', 'with'): 2,
#          ('with', 'newfound'): 1,
#          ('newfound', 'clarity'): 1,
#          ('they', 'went'): 4,
#          ('went', 'to'): 14,
#          ('the', 'concert'): 1,
#          ('concert', 'with'): 1,
#          ('saw', 'their'): 1,
#          ('their', 'favorite'): 1,
#          ('favorite', 'band'): 1,
#          ('band', 'perform'): 1,
#          ('perform', 'live'): 1,
#          ('the', 'artist'): 1,
#          ('artist', 'saw'): 1,
#          ('saw', 'beauty'): 1,
#          ('beauty', 'in'): 2,
#          ('in', 'simplicity'): 1,
#          ('simplicity', 'with'): 1,
#          ('with', 'every'): 1,
#          ('every', 'stroke'): 1,
#          ('stroke', 'of'): 1,
#          ('of', 'the'): 1,
#          ('the', 'brush'): 1,
#          ('sarah', 'went'): 2,
#          ('went', 'for'): 1,
#          ('a', 'hike'): 1,
#          ('hike', 'with'): 1,
#          ('saw', 'a'): 3,
#          ('a', 'rare'): 1,
#          ('rare', 'bird'): 1,
#          ('bird', 'in'): 1,
#          ('the', 'forest'): 1,
#          ('the', 'future'): 1,
#          ('future', 'with'): 1,
#          ('with', 'uncertainty'): 1,
#          ('uncertainty', 'looming'): 1,
#          ('the', 'tourist'): 1,
#          ('tourist', 'explored'): 1,
#          ('explored', 'the'): 1,
#          ('the', 'city'): 1,
#          ('city', 'with'): 1,
#          ('saw', 'famous'): 1,
#          ('famous', 'landmarks'): 1,
#          ('the', 'mist'): 1,
#          ('mist', 'with'): 1,
#          ('a', 'steady'): 1,
#          ('steady', 'gaze'): 1,
#          ('he', 'attended'): 1,
#          ('attended', 'the'): 1,
#          ('conference', 'with'): 1,
#          ('saw', 'inspiring'): 1,
#          ('inspiring', 'speakers'): 1,
#          ('speakers', 'on'): 1,
#          ('the', 'truth'): 1,
#          ('truth', 'with'): 1,
#          ('with', 'unclouded'): 1,
#          ('unclouded', 'vision'): 1,
#          ('they', 'visited'): 1,
#          ('visited', 'the'): 1,
#          ('the', 'art'): 1,
#          ('art', 'gallery'): 1,
#          ('gallery', 'with'): 1,
#          ('saw', 'stunning'): 1,
#          ('stunning', 'paintings'): 1,
#          ('paintings', 'and'): 1,
#          ('and', 'sculptures'): 1,
#          ('the', 'detective'): 1,
#          ('detective', 'saw'): 1,
#          ('the', 'suspect'): 1,
#          ('suspect', 'alibi'): 1,
#          ('alibi', 'with'): 1,
#          ('with', 'careful'): 1,
#          ('careful', 'scrutiny'): 1,
#          ('she', 'went'): 3,
#          ('the', 'beach'): 1,
#          ('beach', 'with'): 1,
#          ('saw', 'dolphins'): 1,
#          ('dolphins', 'swimming'): 1,
#          ('swimming', 'in'): 1,
#          ('the', 'ocean'): 1,
#          ('the', 'potential'): 1,
#          ('potential', 'in'): 1,
#          ('the', 'project'): 1,
#          ('project', 'with'): 1,
#          ('a', 'fresh'): 1,
#          ('fresh', 'perspective'): 1,
#          ('john', 'went'): 2,
#          ('saw', 'ancient'): 1,
#          ('ancient', 'artifacts'): 1,
#          ('artifacts', 'from'): 2,
#          ('from', 'different'): 1,
#          ('different', 'cultures'): 1,
#          ('the', 'flaws'): 1,
#          ('flaws', 'in'): 1,
#          ('the', 'plan'): 1,
#          ('plan', 'with'): 1,
#          ('with', 'critical'): 1,
#          ('critical', 'analysis'): 1,
#          ('the', 'student'): 1,
#          ('student', 'went'): 1,
#          ('the', 'library'): 1,
#          ('library', 'with'): 1,
#          ('saw', 'rows'): 1,
#          ('rows', 'of'): 1,
#          ('of', 'books'): 1,
#          ('books', 'on'): 1,
#          ('on', 'various'): 1,
#          ('various', 'subjects'): 1,
#          ('the', 'humor'): 1,
#          ('humor', 'in'): 1,
#          ('the', 'situation'): 1,
#          ('situation', 'with'): 1,
#          ('a', 'shared'): 1,
#          ('shared', 'laugh'): 1,
#          ('he', 'went'): 3,
#          ('the', 'zoo'): 1,
#          ('zoo', 'with'): 1,
#          ('saw', 'exotic'): 1,
#          ('exotic', 'animals'): 1,
#          ('animals', 'from'): 1,
#          ('from', 'around'): 1,
#          ('the', 'opportunity'): 1,
#          ('opportunity', 'with'): 1,
#          ('of', 'excitement'): 1,
#          ('the', 'amusement'): 1,
#          ('amusement', 'park'): 1,
#          ('saw', 'thrilling'): 1,
#          ('thrilling', 'rides'): 1,
#          ('rides', 'and'): 1,
#          ('and', 'attractions'): 1,
#          ('the', 'chaos'): 1,
#          ('chaos', 'unfolding'): 1,
#          ('unfolding', 'with'): 1,
#          ('of', 'urgency'): 1,
#          ('the', 'botanical'): 1,
#          ('botanical', 'garden'): 1,
#          ('garden', 'with'): 1,
#          ('saw', 'colorful'): 1,
#          ('colorful', 'flowers'): 1,
#          ('flowers', 'and'): 1,
#          ('and', 'plants'): 1,
#          ('the', 'stars'): 1,
#          ('stars', 'with'): 1,
#          ('with', 'wonder'): 1,
#          ('the', 'aquarium'): 1,
#          ('aquarium', 'with'): 1,
#          ('saw', 'diverse'): 1,
#          ('diverse', 'marine'): 1,
#          ('marine', 'life'): 1,
#          ('the', 'scientist'): 1,
#          ('scientist', 'saw'): 1,
#          ('saw', 'patterns'): 1,
#          ('patterns', 'emerge'): 1,
#          ('emerge', 'with'): 1,
#          ('with', 'each'): 1,
#          ('each', 'experiment'): 1,
#          ('the', 'theater'): 1,
#          ('theater', 'with'): 1,
#          ('a', 'captivating'): 1,
#          ('captivating', 'play'): 1,
#          ('the', 'beauty'): 1,
#          ('in', 'imperfection'): 1,
#          ('imperfection', 'with'): 1,
#          ('with', 'an'): 1,
#          ('an', 'artist'): 1,
#          ('artist', 'eye'): 1,
#          ('the', 'market'): 1,
#          ('market', 'with'): 1,
#          ('saw', 'fresh'): 1,
#          ('fresh', 'produce'): 1,
#          ('produce', 'and'): 1,
#          ('and', 'local'): 1,
#          ('local', 'goods'): 1,
#          ('the', 'danger'): 1,
#          ('danger', 'ahead'): 1,
#          ('ahead', 'with'): 2,
#          ('a', 'quick'): 1,
#          ('quick', 'assessment'): 1,
#          ('the', 'observatory'): 1,
#          ('observatory', 'with'): 1,
#          ('saw', 'distant'): 1,
#          ('distant', 'galaxies'): 1,
#          ('galaxies', 'through'): 1,
#          ('through', 'a'): 1,
#          ('a', 'telescope'): 1,
#          ('the', 'challenges'): 1,
#          ('challenges', 'ahead'): 1,
#          ('with', 'determination'): 1,
#          ('determination', 'in'): 1,
#          ('their', 'hearts'): 1,
#          ('the', 'sports'): 1,
#          ('sports', 'stadium'): 1,
#          ('stadium', 'with'): 1,
#          ('saw', 'an'): 1,
#          ('an', 'intense'): 1,
#          ('intense', 'match'): 1,
#          ('match', 'between'): 1,
#          ('between', 'rival'): 1,
#          ('rival', 'teams'): 1,
#          ('the', 'explorer'): 1,
#          ('explorer', 'saw'): 1,
#          ('of', 'adventure'): 1,
#          ('the', 'planetarium'): 1,
#          ('planetarium', 'with'): 1,
#          ('a', 'fascinating'): 1,
#          ('fascinating', 'presentation'): 1,
#          ('presentation', 'about'): 1,
#          ('about', 'the'): 1,
#          ('the', 'cosmos'): 1,
#          ('the', 'silver'): 1,
#          ('silver', 'lining'): 1,
#          ('lining', 'in'): 1,
#          ('in', 'every'): 1,
#          ('every', 'cloud'): 1,
#          ('cloud', 'with'): 1,
#          ('with', 'optimism'): 1,
#          ('the', 'historic'): 1,
#          ('historic', 'site'): 1,
#          ('site', 'with'): 1,
#          ('saw', 'artifacts'): 1,
#          ('from', 'ancient'): 1,
#          ('ancient', 'civilizations'): 1})

# %%
import math
prep = input("Enter the Preposition : ")
noun = input("Enter the Noun : ")
verb = input("Enter the Verb :")
c_n = token_count.get(noun,0)+1
c_v = token_count.get(verb,0)+1
c_pn = bigram_count.get((prep,noun),0)+1
c_pv = bigram_count.get((prep,noun),0)+1
p_pn = c_pn/c_n
p_pv = c_pv/c_v
p_npn = 1 - p_pn
lamda = math.log((p_pv * p_npn/p_pn),2)
if lamda > 0 :
    print("Verb")
else :
    print("Noun")
# Out:
# Enter the Preposition :  in
# Enter the Noun :  cloud
# Enter the Verb : saw
# Noun
